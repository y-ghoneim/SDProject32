# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df = pd.read_csv('..\Dataset\Physiology_Formatted_Dataset_v2.csv')
df = df.dropna()
df
# Out:
#      patient_id               Window  Body Temperature  \
# 2         0697d  2019-06-28 14:00:00         36.599000
# 3         0697d  2019-06-28 14:30:00         36.599000
# 5         0697d  2019-06-29 17:00:00         36.914833
# 6         0697d  2019-06-29 17:30:00         36.743750
# 10        099bc  2019-05-15 11:30:00         37.229286
# ...         ...                  ...               ...
# 7156      eca1f  2019-06-28 10:00:00         36.322000
# 7157      eca1f  2019-06-30 14:00:00         36.934000
# 7158      eca1f  2019-06-30 14:30:00         36.934000
# 7270      fd100  2019-06-27 11:00:00         36.699600
# 7271      fd100  2019-06-27 11:30:00         36.703000
#
#       Diastolic Blood Pressure  Heart Rate  O/E - Muscle Mass  \
# 2                         82.0        42.0               64.5
# 3                         82.0        42.0               64.5
# 5                         78.5        60.0               64.6
# 6                         78.5        60.0               64.6
# 10                        88.0        66.0               39.8
# ...                        ...         ...                ...
# 7156                      68.0        91.0               48.0
# 7157                      71.0        87.0               48.3
# 7158                      71.0        87.0               48.3
# 7270                      76.0        54.0               37.5
# 7271                      76.0        54.0               37.5
#
#       Systolic Blood Pressure  Agitation         day
# 2                       165.0          0  2019-06-28
# 3                       165.0          0  2019-06-28
# 5                       157.0          0  2019-06-29
# 6                       157.0          0  2019-06-29
# 10                      141.0          1  2019-05-15
# ...                       ...        ...         ...
# 7156                    107.0          1  2019-06-28
# 7157                    129.0          0  2019-06-30
# 7158                    129.0          0  2019-06-30
# 7270                    153.0          0  2019-06-27
# 7271                    153.0          0  2019-06-27
#
# [2353 rows x 9 columns]

# %%
df.drop(['patient_id', 'Window', 'day'], axis=1).corr()
# Out:
#                           Body Temperature  Diastolic Blood Pressure  \
# Body Temperature                  1.000000                 -0.126725
# Diastolic Blood Pressure         -0.126725                  1.000000
# Heart Rate                       -0.030566                  0.094320
# O/E - Muscle Mass                -0.102124                 -0.147124
# Systolic Blood Pressure          -0.118660                  0.729956
# Agitation                        -0.061135                  0.070183
#
#                           Heart Rate  O/E - Muscle Mass  \
# Body Temperature           -0.030566          -0.102124
# Diastolic Blood Pressure    0.094320          -0.147124
# Heart Rate                  1.000000          -0.046248
# O/E - Muscle Mass          -0.046248           1.000000
# Systolic Blood Pressure    -0.053564          -0.201209
# Agitation                   0.049280           0.164679
#
#                           Systolic Blood Pressure  Agitation
# Body Temperature                        -0.118660  -0.061135
# Diastolic Blood Pressure                 0.729956   0.070183
# Heart Rate                              -0.053564   0.049280
# O/E - Muscle Mass                       -0.201209   0.164679
# Systolic Blood Pressure                  1.000000   0.067277
# Agitation                                0.067277   1.000000

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['Agitation', 'patient_id', 'Window', 'day'], axis=1), df['Agitation'], test_size=0.2, random_state=42)

# Create a random forest classifier
clf = RandomForestClassifier()

# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

clf.fit(X_train, y_train)

#print classification report on test set
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       260
#            1       0.93      0.97      0.95       211
#
#     accuracy                           0.95       471
#    macro avg       0.95      0.96      0.95       471
# weighted avg       0.95      0.95      0.95       471
