# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df = pd.read_csv('..\Dataset\Physiology_Formatted_Dataset_V2.csv')
df = df.dropna()
df
# Out:
#      patient_id               Window  Body Temperature  \
# 0         0697d  2019-06-28 14:00:00         36.599000
# 1         0697d  2019-06-28 14:30:00         36.599000
# 2         0697d  2019-06-29 17:00:00         36.914833
# 3         0697d  2019-06-29 17:30:00         36.743750
# 4         099bc  2019-05-15 11:30:00         37.229286
# ...         ...                  ...               ...
# 2604      eca1f  2019-06-28 10:00:00         36.322000
# 2605      eca1f  2019-06-30 14:00:00         36.934000
# 2606      eca1f  2019-06-30 14:30:00         36.934000
# 2607      fd100  2019-06-27 11:00:00         36.699600
# 2608      fd100  2019-06-27 11:30:00         36.703000
#
#       Diastolic Blood Pressure  Heart Rate  Body weight  \
# 0                         82.0        42.0         86.3
# 1                         82.0        42.0         86.3
# 2                         78.5        60.0         86.1
# 3                         78.5        60.0         86.1
# ...

# %%
df.drop(['patient_id', 'Window', 'day'], axis=1).corr()
# Out:
#                           Body Temperature  Diastolic Blood Pressure  \
# Body Temperature                  1.000000                 -0.138034
# Diastolic Blood Pressure         -0.138034                  1.000000
# Heart Rate                        0.002970                  0.097309
# Body weight                      -0.052708                 -0.022281
# Systolic Blood Pressure          -0.123427                  0.728124
# Agitation                        -0.019446                  0.098102
#
#                           Heart Rate  Body weight  Systolic Blood Pressure  \
# Body Temperature            0.002970    -0.052708                -0.123427
# Diastolic Blood Pressure    0.097309    -0.022281                 0.728124
# Heart Rate                  1.000000    -0.147277                -0.045441
# Body weight                -0.147277     1.000000                -0.017724
# Systolic Blood Pressure    -0.045441    -0.017724                 1.000000
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['Agitation', 'patient_id', 'Window', 'day'], axis=1), df['Agitation'], test_size=0.2, random_state=42)

# Create a random forest classifier
clf = RandomForestClassifier()

# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

clf.fit(X_train, y_train)

#print classification report on test set
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       260
#            1       0.93      0.97      0.95       211
#
#     accuracy                           0.95       471
#    macro avg       0.95      0.96      0.95       471
# weighted avg       0.95      0.95      0.95       471

# %%
#run logistic regression
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

#print classification report on test set
print(classification_report(y_test, log_reg.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.68      0.64       260
#            1       0.53      0.45      0.49       211
#
#     accuracy                           0.58       471
#    macro avg       0.57      0.57      0.56       471
# weighted avg       0.57      0.58      0.57       471
